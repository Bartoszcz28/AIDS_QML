# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import random as rn

from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.base import BaseEstimator, TransformerMixin

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.metrics import classification_report
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_curve, auc

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping


np.random.seed(42)
rn.seed(42)
tf.random.set_seed(42)

# %%
aids = pd.read_csv('data/AIDS_Classification.csv')

# %%
aids.head()
# Out:
#    time  trt  age     wtkg  hemo  homo  drugs  karnof  oprior  z30  ...  str2  \
# 0   948    2   48  89.8128     0     0      0     100       0    0  ...     0
# 1  1002    3   61  49.4424     0     0      0      90       0    1  ...     1
# 2   961    3   45  88.4520     0     1      1      90       0    1  ...     1
# 3  1166    3   47  85.2768     0     1      0     100       0    1  ...     1
# 4  1090    0   43  66.6792     0     1      0     100       0    1  ...     1
#
#    strat  symptom  treat  offtrt  cd40  cd420  cd80  cd820  infected
# 0      1        0      1       0   422    477   566    324         0
# 1      3        0      1       0   162    218   392    564         1
# 2      3        0      1       1   326    274  2063   1893         0
# 3      3        0      1       0   287    394  1590    966         0
# 4      3        0      0       0   504    353   870    782         0
#
# [5 rows x 23 columns]

# %%
aids.drop(columns={'z30', 'treat','str2', 'cd420','cd820'}, inplace=True)

# %%
aids.shape
# Out:
# (2139, 18)

# %%
aids.describe()
# Out:
#               time          trt          age         wtkg         hemo  \
# count  2139.000000  2139.000000  2139.000000  2139.000000  2139.000000
# mean    879.098177     1.520804    35.248247    75.125311     0.084151
# std     292.274324     1.127890     8.709026    13.263164     0.277680
# min      14.000000     0.000000    12.000000    31.000000     0.000000
# 25%     727.000000     1.000000    29.000000    66.679200     0.000000
# 50%     997.000000     2.000000    34.000000    74.390400     0.000000
# 75%    1091.000000     3.000000    40.000000    82.555200     0.000000
# max    1231.000000     3.000000    70.000000   159.939360     1.000000
#
#               homo        drugs       karnof       oprior      preanti  \
# count  2139.000000  2139.000000  2139.000000  2139.000000  2139.000000
# mean      0.661057     0.131370    95.446470     0.021973   379.175783
# std       0.473461     0.337883     5.900985     0.146629   468.657526
# min       0.000000     0.000000    70.000000     0.000000     0.000000
# 25%       0.000000     0.000000    90.000000     0.000000     0.000000
# 50%       1.000000     0.000000   100.000000     0.000000   142.000000
# 75%       1.000000     0.000000   100.000000     0.000000   739.500000
# max       1.000000     1.000000   100.000000     1.000000  2851.000000
#
#               race       gender        strat      symptom       offtrt  \
# count  2139.000000  2139.000000  2139.000000  2139.000000  2139.000000
# mean      0.288453     0.827957     1.979897     0.172978     0.362786
# std       0.453149     0.377506     0.899053     0.378317     0.480916
# min       0.000000     0.000000     1.000000     0.000000     0.000000
# 25%       0.000000     1.000000     1.000000     0.000000     0.000000
# 50%       0.000000     1.000000     2.000000     0.000000     0.000000
# 75%       1.000000     1.000000     3.000000     0.000000     1.000000
# max       1.000000     1.000000     3.000000     1.000000     1.000000
#
#               cd40         cd80     infected
# count  2139.000000  2139.000000  2139.000000
# mean    350.501169   986.627396     0.243572
# std     118.573863   480.197750     0.429338
# min       0.000000    40.000000     0.000000
# 25%     263.500000   654.000000     0.000000
# 50%     340.000000   893.000000     0.000000
# 75%     423.000000  1207.000000     0.000000
# max    1199.000000  5011.000000     1.000000

# %%
aids.corr().sort_values('infected',ascending=False)['infected']
# Out:
# infected    1.000000
# strat       0.131441
# symptom     0.129234
# preanti     0.128453
# offtrt      0.092850
# age         0.070384
# cd80        0.065338
# homo        0.054279
# gender      0.045118
# oprior      0.041251
# wtkg        0.016205
# hemo       -0.011154
# drugs      -0.049794
# race       -0.055977
# trt        -0.084360
# karnof     -0.102944
# cd40       -0.185647
# time       -0.574989
# Name: infected, dtype: float64

# %%
class DataFrameTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, transformer, original_columns):
        self.transformer = transformer
        self.original_columns = original_columns
    
    def fit(self, X, y=None):
        self.transformer.fit(X, y)
        return self
    
    def transform(self, X, y=None):
        X_transformed = self.transformer.transform(X)
        if not isinstance(X_transformed, pd.DataFrame):
            X_transformed = pd.DataFrame(X_transformed, columns=self.get_feature_names_out())
        
        original_data = X[self.original_columns]
        
        X_final = pd.concat([original_data.reset_index(drop=True), X_transformed.reset_index(drop=True)], axis=1)
        return X_final
    
    def get_feature_names_out(self):
        return self.transformer.get_feature_names_out()

# %%
cols_to_scale = ['time', 'age', 'wtkg', 'karnof', 'preanti', 'cd40', 'cd80']
cols_to_one_hot = ['trt', 'strat']
orginal_columns = [col for col in aids.columns if col not in (cols_to_scale + cols_to_one_hot)]

preprocessor = ColumnTransformer(transformers = [
    ('numerical', StandardScaler(), cols_to_scale),
    ('one_hot', OneHotEncoder(drop='first'), cols_to_one_hot)
])

pipe = Pipeline(steps = [
                ('preprocessor', DataFrameTransformer(preprocessor, orginal_columns)),
])

# joblib.dump(pipe, 'models/data_transformer.pkl')

aids_t = pipe.fit_transform(aids)

aids_t.to_csv('data/aids_t.csv')

# %%
X = aids_t.drop(columns=['infected'])
y = aids_t['infected']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
def metrics(siec):
    # Przewidywanie wartości na zbiorze treningwym

    print('Metryki dla zbioru treningowego')
    print('-'*50)

    y_pred_prob = siec.predict(X_train)
    y_pred = (y_pred_prob > 0.5).astype(int)

    # Obliczanie metryk
    accuracy = accuracy_score(y_train, y_pred)
    conf_matrix = confusion_matrix(y_train, y_pred)
    class_report = classification_report(y_train, y_pred, digits =4)

    print("Accuracy:", accuracy)
    print("Confusion Matrix:\n", conf_matrix)
    print("Classification Report:\n", class_report)

    print('Metryki dla zbioru testowego')
    print('-'*50)

    # Przewidywanie wartości na zbiorze testowym
    y_pred_prob = siec.predict(X_test)
    y_pred = (y_pred_prob > 0.5).astype(int)

    # Obliczanie metryk
    accuracy = accuracy_score(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)
    class_report = classification_report(y_test, y_pred, digits =4)

    print("Accuracy:", accuracy)
    print("Confusion Matrix:\n", conf_matrix)
    print("Classification Report:\n", class_report)

# %%
# Ustawienie ziarna dla generatorów liczb losowych
np.random.seed(42)   # Ustawienie ziarna dla numpy
rn.seed(42)          # Ustawienie ziarna dla modułu random
tf.random.set_seed(42)  # Ustawienie ziarna dla TensorFlow

# Tworzenie modelu sekwencyjnego
siec1 = Sequential()

# Dodanie warstwy Dense z 3 neuronami, funkcją aktywacji ReLU i odpowiednim wymiarem wejściowym
siec1.add(Dense(3, input_dim=X_train.shape[1], activation='relu'))

# Dodanie warstwy Dense z 1 neuronem i funkcją aktywacji sigmoidalną (dla klasyfikacji binarnej)
siec1.add(Dense(1, activation='sigmoid'))

# Kompilacja modelu z użyciem binary_crossentropy jako funkcji straty i optymalizatorem adam
siec1.compile(loss='binary_crossentropy', optimizer='adam')

# Trenowanie modelu na danych X_train, y_train przez 50 epok, z rozmiarem batcha równym 50 i podziale walidacyjnym 20%
siec1.fit(X_train, y_train, epochs=50, batch_size=50, validation_split=0.2)
# Out:
# Epoch 1/50
# c:\Users\Bartosz\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.2005 - val_loss: 1.0510
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0892 - val_loss: 0.9670
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9961 - val_loss: 0.8969
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9189 - val_loss: 0.8388
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8551 - val_loss: 0.7910
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8017 - val_loss: 0.7511
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7577 - val_loss: 0.7193
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7218 - val_loss: 0.6933
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6910 - val_loss: 0.6712
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6643 - val_loss: 0.6524
# Epoch 11/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6414 - val_loss: 0.6362
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6225 - val_loss: 0.6217
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6065 - val_loss: 0.6086
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5928 - val_loss: 0.5967
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5810 - val_loss: 0.5856
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5706 - val_loss: 0.5747
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5609 - val_loss: 0.5641
# Epoch 18/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5516 - val_loss: 0.5535
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5418 - val_loss: 0.5420
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5314 - val_loss: 0.5289
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5208 - val_loss: 0.5151
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5092 - val_loss: 0.4994
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4957 - val_loss: 0.4828
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4813 - val_loss: 0.4660
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4666 - val_loss: 0.4507
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4526 - val_loss: 0.4350
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4387 - val_loss: 0.4205
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4256 - val_loss: 0.4084
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4138 - val_loss: 0.3978
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4031 - val_loss: 0.3884
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3938 - val_loss: 0.3807
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3862 - val_loss: 0.3742
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3798 - val_loss: 0.3688
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3743 - val_loss: 0.3643
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3697 - val_loss: 0.3604
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3658 - val_loss: 0.3573
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3625 - val_loss: 0.3547
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3596 - val_loss: 0.3525
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3571 - val_loss: 0.3506
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3550 - val_loss: 0.3490
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3530 - val_loss: 0.3476
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3512 - val_loss: 0.3463
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3497 - val_loss: 0.3453
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3483 - val_loss: 0.3443
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3472 - val_loss: 0.3435
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3461 - val_loss: 0.3427
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3450 - val_loss: 0.3421
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3439 - val_loss: 0.3416
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3430 - val_loss: 0.3411
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3422 - val_loss: 0.3407

# %%
metrics(siec1)
# Out:
# Metryki dla zbioru treningowego
# --------------------------------------------------
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step
# Accuracy: 0.8591022443890274
# Confusion Matrix:
#  [[1145   68]
#  [ 158  233]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.8787    0.9439    0.9102      1213
#            1     0.7741    0.5959    0.6734       391
#
#     accuracy                         0.8591      1604
#    macro avg     0.8264    0.7699    0.7918      1604
# weighted avg     0.8532    0.8591    0.8525      1604
#
# Metryki dla zbioru testowego
# --------------------------------------------------
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step
# Accuracy: 0.8392523364485981
# Confusion Matrix:
#  [[380  25]
#  [ 61  69]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.8617    0.9383    0.8983       405
#            1     0.7340    0.5308    0.6161       130
#
#     accuracy                         0.8393       535
#    macro avg     0.7979    0.7345    0.7572       535
# weighted avg     0.8307    0.8393    0.8298       535

# %%
import seaborn as sns
import matplotlib.pyplot as plt

y_pred_prob = siec1.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

conf_matrix = confusion_matrix(y_test, y_pred, labels=[0, 1])

# Definicja etykiet klas
class_labels = ['Negative (0)', 'Positive (1)']

# Wyświetlenie macierzy pomyłek z opisami
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels, annot_kws={"fontsize":15})
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step

# %%
import matplotlib.pyplot as plt

y_pred_prob = siec1.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step

# %%
# Przygotowanie modelu sieci neuronowej z regularizacją i Dropout
siec2 = Sequential()
siec2.add(Dense(2, input_dim=X_train.shape[1], activation='relu', kernel_regularizer=l2(0.01)))
siec2.add(Dropout(0.2))
siec2.add(Dense(1, activation='sigmoid'))

# Kompilacja modelu
siec2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Wczesne zatrzymanie
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Uczenie modelu z walidacją
siec2.fit(X_train, y_train, epochs=100, batch_size=10, 
          validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# c:\Users\Bartosz\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6612 - loss: 0.7654 - val_accuracy: 0.6885 - val_loss: 0.6786
# Epoch 2/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - accuracy: 0.7459 - loss: 0.6457 - val_accuracy: 0.7165 - val_loss: 0.6137
# Epoch 3/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - accuracy: 0.7606 - loss: 0.5967 - val_accuracy: 0.7352 - val_loss: 0.5663
# Epoch 4/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 0.7676 - loss: 0.5486 - val_accuracy: 0.7445 - val_loss: 0.5311
# Epoch 5/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - accuracy: 0.7731 - loss: 0.5254 - val_accuracy: 0.7477 - val_loss: 0.5053
# Epoch 6/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 0.7657 - loss: 0.5049 - val_accuracy: 0.7477 - val_loss: 0.4857
# Epoch 7/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7761 - loss: 0.4842 - val_accuracy: 0.7508 - val_loss: 0.4695
# Epoch 8/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7744 - loss: 0.4896 - val_accuracy: 0.7539 - val_loss: 0.4567
# Epoch 9/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7721 - loss: 0.4636 - val_accuracy: 0.7570 - val_loss: 0.4443
# Epoch 10/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.7811 - loss: 0.4690 - val_accuracy: 0.7601 - val_loss: 0.4310
# Epoch 11/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 0.7936 - loss: 0.4600 - val_accuracy: 0.7975 - val_loss: 0.4127
# Epoch 12/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - accuracy: 0.8198 - loss: 0.4385 - val_accuracy: 0.8224 - val_loss: 0.3944
# Epoch 13/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 0.8116 - loss: 0.4278 - val_accuracy: 0.8505 - val_loss: 0.3770
# Epoch 14/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.8364 - loss: 0.4117 - val_accuracy: 0.8567 - val_loss: 0.3672
# Epoch 15/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 0.8233 - loss: 0.4178 - val_accuracy: 0.8567 - val_loss: 0.3608
# Epoch 16/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - accuracy: 0.8284 - loss: 0.4050 - val_accuracy: 0.8536 - val_loss: 0.3573
# Epoch 17/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 0.8376 - loss: 0.3941 - val_accuracy: 0.8629 - val_loss: 0.3526
# Epoch 18/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step - accuracy: 0.8320 - loss: 0.4028 - val_accuracy: 0.8598 - val_loss: 0.3492
# Epoch 19/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.8269 - loss: 0.4041 - val_accuracy: 0.8629 - val_loss: 0.3484
# Epoch 20/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - accuracy: 0.8376 - loss: 0.3909 - val_accuracy: 0.8660 - val_loss: 0.3421
# Epoch 21/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - accuracy: 0.8336 - loss: 0.3847 - val_accuracy: 0.8660 - val_loss: 0.3390
# Epoch 22/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.8293 - loss: 0.3804 - val_accuracy: 0.8692 - val_loss: 0.3376
# Epoch 23/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - accuracy: 0.8296 - loss: 0.3936 - val_accuracy: 0.8629 - val_loss: 0.3379
# Epoch 24/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.8349 - loss: 0.3896 - val_accuracy: 0.8598 - val_loss: 0.3401
# Epoch 25/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 0.8335 - loss: 0.3847 - val_accuracy: 0.8660 - val_loss: 0.3347
# Epoch 26/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - accuracy: 0.8299 - loss: 0.3830 - val_accuracy: 0.8660 - val_loss: 0.3336
# Epoch 27/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.8480 - loss: 0.3767 - val_accuracy: 0.8629 - val_loss: 0.3321
# Epoch 28/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - accuracy: 0.8368 - loss: 0.3958 - val_accuracy: 0.8660 - val_loss: 0.3332
# Epoch 29/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - accuracy: 0.8480 - loss: 0.3708 - val_accuracy: 0.8629 - val_loss: 0.3299
# Epoch 30/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.8271 - loss: 0.3924 - val_accuracy: 0.8629 - val_loss: 0.3256
# Epoch 31/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - accuracy: 0.8358 - loss: 0.3885 - val_accuracy: 0.8692 - val_loss: 0.3264
# Epoch 32/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - accuracy: 0.8422 - loss: 0.3744 - val_accuracy: 0.8629 - val_loss: 0.3271
# Epoch 33/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 0.8424 - loss: 0.3727 - val_accuracy: 0.8629 - val_loss: 0.3256
# Epoch 34/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 0.8395 - loss: 0.3632 - val_accuracy: 0.8660 - val_loss: 0.3237
# Epoch 35/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8358 - loss: 0.3781 - val_accuracy: 0.8692 - val_loss: 0.3249
# Epoch 36/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8323 - loss: 0.3814 - val_accuracy: 0.8660 - val_loss: 0.3270
# Epoch 37/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8366 - loss: 0.3691 - val_accuracy: 0.8660 - val_loss: 0.3235
# Epoch 38/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8347 - loss: 0.3793 - val_accuracy: 0.8629 - val_loss: 0.3244
# Epoch 39/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8386 - loss: 0.3683 - val_accuracy: 0.8629 - val_loss: 0.3233
# Epoch 40/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8421 - loss: 0.3649 - val_accuracy: 0.8660 - val_loss: 0.3200
# Epoch 41/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8420 - loss: 0.3809 - val_accuracy: 0.8692 - val_loss: 0.3197
# Epoch 42/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8495 - loss: 0.3629 - val_accuracy: 0.8754 - val_loss: 0.3175
# Epoch 43/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8447 - loss: 0.3621 - val_accuracy: 0.8754 - val_loss: 0.3176
# Epoch 44/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8243 - loss: 0.3959 - val_accuracy: 0.8723 - val_loss: 0.3181
# Epoch 45/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8529 - loss: 0.3686 - val_accuracy: 0.8754 - val_loss: 0.3141
# Epoch 46/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8383 - loss: 0.3722 - val_accuracy: 0.8723 - val_loss: 0.3153
# Epoch 47/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8573 - loss: 0.3612 - val_accuracy: 0.8723 - val_loss: 0.3155
# Epoch 48/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8452 - loss: 0.3632 - val_accuracy: 0.8629 - val_loss: 0.3176
# Epoch 49/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8507 - loss: 0.3672 - val_accuracy: 0.8692 - val_loss: 0.3149
# Epoch 50/100
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8528 - loss: 0.3657 - val_accuracy: 0.8660 - val_loss: 0.3152

# %%
metrics(siec2)
# Out:
# Metryki dla zbioru treningowego
# --------------------------------------------------
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Accuracy: 0.8721945137157108
# Confusion Matrix:
#  [[1160   53]
#  [ 152  239]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.8841    0.9563    0.9188      1213
#            1     0.8185    0.6113    0.6999       391
#
#     accuracy                         0.8722      1604
#    macro avg     0.8513    0.7838    0.8093      1604
# weighted avg     0.8681    0.8722    0.8654      1604
#
# Metryki dla zbioru testowego
# --------------------------------------------------
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step
# Accuracy: 0.8523364485981308
# Confusion Matrix:
#  [[385  20]
#  [ 59  71]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.8671    0.9506    0.9069       405
#            1     0.7802    0.5462    0.6425       130
#
#     accuracy                         0.8523       535
#    macro avg     0.8237    0.7484    0.7747       535
# weighted avg     0.8460    0.8523    0.8427       535

# %%
y_pred_prob = siec2.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

conf_matrix = confusion_matrix(y_test, y_pred, labels=[0, 1])

# Definicja etykiet klas
class_labels = ['Negative (0)', 'Positive (1)']

# Wyświetlenie macierzy pomyłek z opisami
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels, annot_kws={"fontsize":15})
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step

# %%
y_pred_prob = siec2.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step

# %%
# Przygotowanie bardziej złożonego modelu sieci neuronowej
siec3 = Sequential()
siec3.add(Dense(64, input_dim=X_train.shape[1], activation='relu', kernel_regularizer=l2(0.001)))
siec3.add(Dropout(0.2))
siec3.add(Dense(32, activation='relu', kernel_regularizer=l2(0.001)))
siec3.add(Dropout(0.2))
siec3.add(Dense(16, activation='relu', kernel_regularizer=l2(0.001)))
siec3.add(Dropout(0.2))
siec3.add(Dense(1, activation='sigmoid'))

# Kompilacja modelu
siec3.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Wczesne zatrzymanie z bardziej elastycznymi ustawieniami
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Uczenie modelu z walidacją
siec3.fit(X_train, y_train, epochs=100, batch_size=32, 
          validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# c:\Users\Bartosz\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.7598 - loss: 0.6496 - val_accuracy: 0.7539 - val_loss: 0.5409
# Epoch 2/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7846 - loss: 0.5414 - val_accuracy: 0.8224 - val_loss: 0.4662
# Epoch 3/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8152 - loss: 0.4857 - val_accuracy: 0.8474 - val_loss: 0.4195
# Epoch 4/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8531 - loss: 0.4388 - val_accuracy: 0.8598 - val_loss: 0.3997
# Epoch 5/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8323 - loss: 0.4367 - val_accuracy: 0.8660 - val_loss: 0.3908
# Epoch 6/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8472 - loss: 0.4234 - val_accuracy: 0.8723 - val_loss: 0.3775
# Epoch 7/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8500 - loss: 0.4175 - val_accuracy: 0.8816 - val_loss: 0.3645
# Epoch 8/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8617 - loss: 0.3992 - val_accuracy: 0.8847 - val_loss: 0.3558
# Epoch 9/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8706 - loss: 0.3698 - val_accuracy: 0.8879 - val_loss: 0.3465
# Epoch 10/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8735 - loss: 0.3778 - val_accuracy: 0.8879 - val_loss: 0.3401
# Epoch 11/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8772 - loss: 0.3636 - val_accuracy: 0.8972 - val_loss: 0.3382
# Epoch 12/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8726 - loss: 0.3533 - val_accuracy: 0.9034 - val_loss: 0.3282
# Epoch 13/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8795 - loss: 0.3560 - val_accuracy: 0.9065 - val_loss: 0.3218
# Epoch 14/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8872 - loss: 0.3379 - val_accuracy: 0.9003 - val_loss: 0.3180
# Epoch 15/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8802 - loss: 0.3424 - val_accuracy: 0.9003 - val_loss: 0.3154
# Epoch 16/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8917 - loss: 0.3390 - val_accuracy: 0.9065 - val_loss: 0.3133
# Epoch 17/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8914 - loss: 0.3402 - val_accuracy: 0.9097 - val_loss: 0.3089
# Epoch 18/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8978 - loss: 0.3256 - val_accuracy: 0.8972 - val_loss: 0.3045
# Epoch 19/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8964 - loss: 0.3303 - val_accuracy: 0.8972 - val_loss: 0.3014
# Epoch 20/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8949 - loss: 0.3247 - val_accuracy: 0.8941 - val_loss: 0.3034
# Epoch 21/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8945 - loss: 0.3244 - val_accuracy: 0.9003 - val_loss: 0.2978
# Epoch 22/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8998 - loss: 0.3000 - val_accuracy: 0.9034 - val_loss: 0.2961
# Epoch 23/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8983 - loss: 0.3010 - val_accuracy: 0.9065 - val_loss: 0.2929
# Epoch 24/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8967 - loss: 0.3076 - val_accuracy: 0.9065 - val_loss: 0.2886
# Epoch 25/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9094 - loss: 0.2923 - val_accuracy: 0.9003 - val_loss: 0.2902
# Epoch 26/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8961 - loss: 0.3089 - val_accuracy: 0.9065 - val_loss: 0.2941
# Epoch 27/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9097 - loss: 0.2815 - val_accuracy: 0.8941 - val_loss: 0.2869
# Epoch 28/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9076 - loss: 0.2944 - val_accuracy: 0.9065 - val_loss: 0.2875
# Epoch 29/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9126 - loss: 0.2916 - val_accuracy: 0.9034 - val_loss: 0.2928
# Epoch 30/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9189 - loss: 0.2817 - val_accuracy: 0.9034 - val_loss: 0.2843
# Epoch 31/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9195 - loss: 0.2793 - val_accuracy: 0.9034 - val_loss: 0.2864
# Epoch 32/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9003 - loss: 0.2959 - val_accuracy: 0.9003 - val_loss: 0.2833
# Epoch 33/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9036 - loss: 0.2788 - val_accuracy: 0.9034 - val_loss: 0.2807
# Epoch 34/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9108 - loss: 0.2714 - val_accuracy: 0.8972 - val_loss: 0.2835
# Epoch 35/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9162 - loss: 0.2656 - val_accuracy: 0.9003 - val_loss: 0.2829
# Epoch 36/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9051 - loss: 0.2725 - val_accuracy: 0.9034 - val_loss: 0.2874
# Epoch 37/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9265 - loss: 0.2490 - val_accuracy: 0.9003 - val_loss: 0.2886
# Epoch 38/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9201 - loss: 0.2562 - val_accuracy: 0.8941 - val_loss: 0.2911
# Epoch 39/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9162 - loss: 0.2593 - val_accuracy: 0.8941 - val_loss: 0.2924
# Epoch 40/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9155 - loss: 0.2674 - val_accuracy: 0.8879 - val_loss: 0.2897
# Epoch 41/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9276 - loss: 0.2467 - val_accuracy: 0.8847 - val_loss: 0.2918
# Epoch 42/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9106 - loss: 0.2573 - val_accuracy: 0.8972 - val_loss: 0.2916
# Epoch 43/100
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9186 - loss: 0.2564 - val_accuracy: 0.9034 - val_loss: 0.2861

# %%
metrics(siec3)
# Out:
# Metryki dla zbioru treningowego
# --------------------------------------------------
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Accuracy: 0.9177057356608479
# Confusion Matrix:
#  [[1155   58]
#  [  74  317]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.9398    0.9522    0.9459      1213
#            1     0.8453    0.8107    0.8277       391
#
#     accuracy                         0.9177      1604
#    macro avg     0.8926    0.8815    0.8868      1604
# weighted avg     0.9168    0.9177    0.9171      1604
#
# Metryki dla zbioru testowego
# --------------------------------------------------
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step
# Accuracy: 0.8878504672897196
# Confusion Matrix:
#  [[380  25]
#  [ 35  95]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.9157    0.9383    0.9268       405
#            1     0.7917    0.7308    0.7600       130
#
#     accuracy                         0.8879       535
#    macro avg     0.8537    0.8345    0.8434       535
# weighted avg     0.8855    0.8879    0.8863       535

# %%
y_pred_prob = siec3.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

conf_matrix = confusion_matrix(y_test, y_pred, labels=[0, 1])

# Definicja etykiet klas
class_labels = ['Negative (0)', 'Positive (1)']

# Wyświetlenie macierzy pomyłek z opisami
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels, annot_kws={"fontsize":15})
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step

# %%
y_pred_prob = siec3.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Predykcje prawdopodobieństw dla każdego modelu
y_pred_prob1 = siec1.predict(X_test)
y_pred_prob2 = siec2.predict(X_test)
y_pred_prob3 = siec3.predict(X_test)

# Obliczanie ROC AUC dla każdego modelu
fpr1, tpr1, _ = roc_curve(y_test, y_pred_prob1)
roc_auc1 = auc(fpr1, tpr1)

fpr2, tpr2, _ = roc_curve(y_test, y_pred_prob2)
roc_auc2 = auc(fpr2, tpr2)

fpr3, tpr3, _ = roc_curve(y_test, y_pred_prob3)
roc_auc3 = auc(fpr3, tpr3)

# Rysowanie krzywych ROC dla wszystkich modeli na jednym wykresie
plt.figure()

plt.plot(fpr1, tpr1, color='blue', lw=2, label='Sieć 1 (area = %0.2f)' % roc_auc1)
plt.plot(fpr2, tpr2, color='darkorange', lw=2, label='Sieć 2 (area = %0.2f)' % roc_auc2)
plt.plot(fpr3, tpr3, color='green', lw=2, label='Sieć 3 (area = %0.2f)' % roc_auc3)

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step

# %%
models = {
    'siec1': {'neurons': 3, 'layers': 1, 'epochs': 50, 'model': siec1},
    'siec2': {'neurons': 2, 'layers': 1, 'epochs': 100, 'model': siec2},
    'siec3': {'neurons': 64, 'layers': 2, 'epochs': 100, 'model': siec3}
}

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score
results = []

for name, info in models.items():
    model = info['model']
    model.fit(X_train, y_train, epochs=info['epochs'], verbose=0)  # Dopasowanie modelu
    y_pred_prob = model.predict(X_test)
    auc = roc_auc_score(y_test, y_pred_prob)
    gini = 2 * auc - 1
    y_pred = (y_pred_prob > 0.5).astype(int)  # Konwersja prawdopodobieństw na etykiety binarne
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    error_rate = 1 - accuracy
    results.append({
        'Model': name,
        'Neurony': info['neurons'],
        'Warstwy ukryte': info['layers'],
        'Epoki': info['epochs'],
        'AUC': auc,
        'Gini': gini,
        'Accuracy': accuracy,
        'F1-score': f1,
        'Error Rate': error_rate
    })

# Tworzenie DataFrame z wynikami
df = pd.DataFrame(results)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step

# %%
df.head()
# Out:
#    Model  Neurony  Warstwy ukryte  Epoki       AUC      Gini  Accuracy  \
# 0  siec1        3               1     50  0.871415  0.742830  0.841121
# 1  siec2        2               1    100  0.931852  0.863704  0.872897
# 2  siec3       64               2    100  0.920019  0.840038  0.874766
#
#    F1-score  Error Rate
# 0  0.622222    0.158879
# 1  0.693694    0.127103
# 2  0.704846    0.125234
